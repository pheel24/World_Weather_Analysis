# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy as citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+"e744b0a3a2a596b21e2a3ecb9a31b02b"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | nanortalik
# Processing Record 8 of Set 1 | erenhot
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | sinnamary
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | pangnirtung
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | karangampel
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | gat
# Processing Record 20 of Set 1 | sosnovo-ozerskoye
# Processing Record 21 of Set 1 | te anau
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | lisala
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | fortuna
# Processing Record 29 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 1 | de-kastri
# Processing Record 31 of Set 1 | sonepur
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | hangzhou
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | karacakoy
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | tommot
# Processing Record 39 of Set 1 | yulara
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | ugoofaaru
# Processing Record 42 of Set 1 | balad
# Processing Record 43 of Set 1 | palmer
# Processing Record 44 of Set 1 | kutum
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | uribia
# Processing Record 48 of Set 1 | santarem
# Processing Record 49 of Set 1 | auchi
# Processing Record 50 of Set 1 | prescott
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | half moon bay
# Processing Record 3 of Set 2 | campbell river
# Processing Record 4 of Set 2 | san patricio
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | neiafu
# Processing Record 7 of Set 2 | xining
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | santander
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | shitanjing
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | barrow
# Processing Record 14 of Set 2 | keti bandar
# Processing Record 15 of Set 2 | thinadhoo
# Processing Record 16 of Set 2 | alice springs
# Processing Record 17 of Set 2 | vulcan
# Processing Record 18 of Set 2 | kruisfontein
# Processing Record 19 of Set 2 | kisangani
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | mount gambier
# Processing Record 22 of Set 2 | waterford
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | ilhabela
# Processing Record 26 of Set 2 | tura
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | gerash
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | bud
# Processing Record 32 of Set 2 | nokha
# Processing Record 33 of Set 2 | sibolga
# Processing Record 34 of Set 2 | cortes
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | kilindoni
# Processing Record 37 of Set 2 | george
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | grindavik
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | bredasdorp
# Processing Record 42 of Set 2 | avarua
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | talcahuano
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | victoria
# Processing Record 48 of Set 2 | kahului
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 50 of Set 2 | ostrovnoy
# Processing Record 1 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 3 | tshikapa
# Processing Record 3 of Set 3 | skjervoy
# Processing Record 4 of Set 3 | mangrol
# Processing Record 5 of Set 3 | tongliao
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | souillac
# Processing Record 8 of Set 3 | tyukhtet
# Processing Record 9 of Set 3 | galesong
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 3 | kodinsk
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | ipixuna
# Processing Record 17 of Set 3 | rabo de peixe
# Processing Record 18 of Set 3 | srednekolymsk
# Processing Record 19 of Set 3 | los llanos de aridane
# Processing Record 20 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 3 | kosice
# Processing Record 22 of Set 3 | bolu
# Processing Record 23 of Set 3 | aguimes
# Processing Record 24 of Set 3 | kodiak
# Processing Record 25 of Set 3 | vilcun
# Processing Record 26 of Set 3 | fort nelson
# Processing Record 27 of Set 3 | west lorne
# Processing Record 28 of Set 3 | christchurch
# Processing Record 29 of Set 3 | dalbandin
# Processing Record 30 of Set 3 | tessalit
# Processing Record 31 of Set 3 | saint-francois
# Processing Record 32 of Set 3 | progreso
# Processing Record 33 of Set 3 | amuntai
# Processing Record 34 of Set 3 | pemberton
# Processing Record 35 of Set 3 | skelleftea
# Processing Record 36 of Set 3 | constantine
# Processing Record 37 of Set 3 | znamenskoye
# Processing Record 38 of Set 3 | tyrma
# Processing Record 39 of Set 3 | xinqing
# Processing Record 40 of Set 3 | waipawa
# Processing Record 41 of Set 3 | komsomolskiy
# Processing Record 42 of Set 3 | asheboro
# Processing Record 43 of Set 3 | russell
# Processing Record 44 of Set 3 | kondopoga
# Processing Record 45 of Set 3 | maragogi
# Processing Record 46 of Set 3 | klaksvik
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | beloha
# Processing Record 49 of Set 3 | esperance
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | visnes
# Processing Record 5 of Set 4 | roebourne
# Processing Record 6 of Set 4 | turukhansk
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | mangai
# Processing Record 9 of Set 4 | cheremnoye
# Processing Record 10 of Set 4 | akdagmadeni
# Processing Record 11 of Set 4 | kavaratti
# Processing Record 12 of Set 4 | havelock
# Processing Record 13 of Set 4 | ranong
# Processing Record 14 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 4 | omaruru
# Processing Record 18 of Set 4 | old road
# City not found. Skipping...
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | ladario
# Processing Record 21 of Set 4 | prince rupert
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | martapura
# Processing Record 25 of Set 4 | hualmay
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | egvekinot
# Processing Record 30 of Set 4 | camocim
# Processing Record 31 of Set 4 | bonfim
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | sioux lookout
# Processing Record 35 of Set 4 | den helder
# Processing Record 36 of Set 4 | marsh harbour
# Processing Record 37 of Set 4 | kortkeros
# Processing Record 38 of Set 4 | finschhafen
# Processing Record 39 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 4 | isetskoye
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | mehamn
# Processing Record 45 of Set 4 | prince albert
# Processing Record 46 of Set 4 | kasongo-lunda
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | inuvik
# Processing Record 49 of Set 4 | saint anthony
# Processing Record 50 of Set 4 | vanimo
# Processing Record 1 of Set 5 | vila do maio
# Processing Record 2 of Set 5 | ukiah
# Processing Record 3 of Set 5 | tagusao
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | vao
# Processing Record 6 of Set 5 | narimanov
# Processing Record 7 of Set 5 | vila velha
# Processing Record 8 of Set 5 | chokurdakh
# Processing Record 9 of Set 5 | arraial do cabo
# Processing Record 10 of Set 5 | karabanovo
# Processing Record 11 of Set 5 | broken hill
# Processing Record 12 of Set 5 | wencheng
# Processing Record 13 of Set 5 | arnprior
# Processing Record 14 of Set 5 | vaitape
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | sibiti
# Processing Record 17 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 5 | verkhoyansk
# Processing Record 19 of Set 5 | port said
# Processing Record 20 of Set 5 | tera
# Processing Record 21 of Set 5 | taltal
# Processing Record 22 of Set 5 | dali
# Processing Record 23 of Set 5 | jalu
# Processing Record 24 of Set 5 | los chiles
# Processing Record 25 of Set 5 | flinders
# Processing Record 26 of Set 5 | puerto madryn
# Processing Record 27 of Set 5 | toppenish
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | umm kaddadah
# Processing Record 31 of Set 5 | zabaykalsk
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | ossora
# Processing Record 34 of Set 5 | pagudpud
# Processing Record 35 of Set 5 | sunbury
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | tateyama
# Processing Record 38 of Set 5 | whyalla
# Processing Record 39 of Set 5 | eyl
# Processing Record 40 of Set 5 | provideniya
# Processing Record 41 of Set 5 | inhambane
# Processing Record 42 of Set 5 | ahipara
# Processing Record 43 of Set 5 | hasaki
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | tambura
# Processing Record 46 of Set 5 | adelaide
# Processing Record 47 of Set 5 | pathein
# Processing Record 48 of Set 5 | naze
# Processing Record 49 of Set 5 | katsuura
# Processing Record 50 of Set 5 | shimoda
# Processing Record 1 of Set 6 | arman
# Processing Record 2 of Set 6 | oranjestad
# Processing Record 3 of Set 6 | huruta
# Processing Record 4 of Set 6 | atar
# Processing Record 5 of Set 6 | barao de melgaco
# Processing Record 6 of Set 6 | matay
# Processing Record 7 of Set 6 | fonte boa
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | syriam
# Processing Record 10 of Set 6 | nhulunbuy
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | henderson
# Processing Record 14 of Set 6 | puerto colombia
# Processing Record 15 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 6 | comodoro rivadavia
# Processing Record 17 of Set 6 | ust-nera
# Processing Record 18 of Set 6 | juneau
# Processing Record 19 of Set 6 | kokstad
# Processing Record 20 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 6 | hobyo
# Processing Record 22 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 23 of Set 6 | dryden
# Processing Record 24 of Set 6 | ati
# Processing Record 25 of Set 6 | price
# Processing Record 26 of Set 6 | melfort
# Processing Record 27 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 6 | khash
# Processing Record 30 of Set 6 | chulman
# Processing Record 31 of Set 6 | cochrane
# Processing Record 32 of Set 6 | cabra
# Processing Record 33 of Set 6 | bay roberts
# Processing Record 34 of Set 6 | okhotsk
# Processing Record 35 of Set 6 | spring hill
# Processing Record 36 of Set 6 | tucurui
# Processing Record 37 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 6 | ochakiv
# Processing Record 39 of Set 6 | gazojak
# Processing Record 40 of Set 6 | dunda
# Processing Record 41 of Set 6 | yerbogachen
# Processing Record 42 of Set 6 | nelson bay
# Processing Record 43 of Set 6 | ponta do sol
# Processing Record 44 of Set 6 | emerald
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | inderka
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | kesennuma
# City not found. Skipping...
# Processing Record 49 of Set 6 | saint-pierre
# Processing Record 50 of Set 6 | brae
# Processing Record 1 of Set 7 | marsabit
# Processing Record 2 of Set 7 | buala
# Processing Record 3 of Set 7 | maues
# Processing Record 4 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | vallenar
# Processing Record 7 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 7 | tiznit
# Processing Record 9 of Set 7 | santa cruz
# Processing Record 10 of Set 7 | port-gentil
# Processing Record 11 of Set 7 | aktash
# Processing Record 12 of Set 7 | balingasay
# Processing Record 13 of Set 7 | reconquista
# Processing Record 14 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 7 | katobu
# Processing Record 16 of Set 7 | snezhnogorsk
# Processing Record 17 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 7 | seydi
# Processing Record 19 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 7 | robertsport
# Processing Record 21 of Set 7 | santiago del estero
# Processing Record 22 of Set 7 | lethem
# Processing Record 23 of Set 7 | kaseda
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | osakarovka
# Processing Record 26 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 7 | ust-tsilma
# Processing Record 29 of Set 7 | muros
# Processing Record 30 of Set 7 | esso
# Processing Record 31 of Set 7 | kaitangata
# Processing Record 32 of Set 7 | dnestrovsc
# Processing Record 33 of Set 7 | magaria
# Processing Record 34 of Set 7 | ternate
# Processing Record 35 of Set 7 | antofagasta
# Processing Record 36 of Set 7 | el balyana
# City not found. Skipping...
# Processing Record 37 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 7 | seoul
# Processing Record 39 of Set 7 | rio grande
# Processing Record 40 of Set 7 | vastervik
# City not found. Skipping...
# Processing Record 41 of Set 7 | mayo
# Processing Record 42 of Set 7 | saint george
# Processing Record 43 of Set 7 | bagdarin
# Processing Record 44 of Set 7 | bonthe
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | cairns
# Processing Record 47 of Set 7 | laguna
# Processing Record 48 of Set 7 | poya
# Processing Record 49 of Set 7 | faya
# Processing Record 50 of Set 7 | belmonte
# Processing Record 1 of Set 8 | bardiyah
# Processing Record 2 of Set 8 | saravan
# Processing Record 3 of Set 8 | takoradi
# Processing Record 4 of Set 8 | darhan
# Processing Record 5 of Set 8 | college
# Processing Record 6 of Set 8 | port townsend
# Processing Record 7 of Set 8 | qui nhon
# Processing Record 8 of Set 8 | broome
# Processing Record 9 of Set 8 | upernavik
# Processing Record 10 of Set 8 | tehachapi
# Processing Record 11 of Set 8 | narsaq
# Processing Record 12 of Set 8 | husavik
# Processing Record 13 of Set 8 | acarau
# Processing Record 14 of Set 8 | barcelos
# Processing Record 15 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 8 | llanes
# Processing Record 17 of Set 8 | fairbanks
# Processing Record 18 of Set 8 | amahai
# Processing Record 19 of Set 8 | ninghai
# Processing Record 20 of Set 8 | geraldton
# Processing Record 21 of Set 8 | the valley
# Processing Record 22 of Set 8 | guayaramerin
# Processing Record 23 of Set 8 | san marcos
# Processing Record 24 of Set 8 | heishan
# Processing Record 25 of Set 8 | pimentel
# Processing Record 26 of Set 8 | concepcion del uruguay
# Processing Record 27 of Set 8 | coihaique
# Processing Record 28 of Set 8 | parana
# Processing Record 29 of Set 8 | kyzyl-suu
# Processing Record 30 of Set 8 | dharmadam
# Processing Record 31 of Set 8 | mount isa
# Processing Record 32 of Set 8 | marzuq
# Processing Record 33 of Set 8 | himora
# City not found. Skipping...
# Processing Record 34 of Set 8 | tiszadob
# Processing Record 35 of Set 8 | morristown
# Processing Record 36 of Set 8 | constitucion
# Processing Record 37 of Set 8 | nabire
# Processing Record 38 of Set 8 | pampa
# Processing Record 39 of Set 8 | chateauroux
# Processing Record 40 of Set 8 | ballina
# Processing Record 41 of Set 8 | rosehearty
# Processing Record 42 of Set 8 | middletown
# Processing Record 43 of Set 8 | zwedru
# Processing Record 44 of Set 8 | ust-maya
# Processing Record 45 of Set 8 | tutoia
# Processing Record 46 of Set 8 | houma
# Processing Record 47 of Set 8 | chililabombwe
# Processing Record 48 of Set 8 | mokhsogollokh
# Processing Record 49 of Set 8 | belaya gora
# Processing Record 50 of Set 8 | camacha
# Processing Record 1 of Set 9 | suluq
# Processing Record 2 of Set 9 | nador
# Processing Record 3 of Set 9 | severobaykalsk
# Processing Record 4 of Set 9 | airai
# Processing Record 5 of Set 9 | baykit
# Processing Record 6 of Set 9 | saryg-sep
# Processing Record 7 of Set 9 | dengzhou
# Processing Record 8 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 9 | jacqueville
# Processing Record 10 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 9 | beringovskiy
# Processing Record 12 of Set 9 | jibuti
# Processing Record 13 of Set 9 | neubrandenburg
# Processing Record 14 of Set 9 | high level
# Processing Record 15 of Set 9 | quelimane
# Processing Record 16 of Set 9 | usogorsk
# Processing Record 17 of Set 9 | yarada
# Processing Record 18 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 9 | sorland
# Processing Record 20 of Set 9 | chapais
# Processing Record 21 of Set 9 | tecoanapa
# Processing Record 22 of Set 9 | villa bruzual
# Processing Record 23 of Set 9 | sao joao dos patos
# Processing Record 24 of Set 9 | jakar
# Processing Record 25 of Set 9 | gali
# Processing Record 26 of Set 9 | nuuk
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | tizimin
# Processing Record 29 of Set 9 | westport
# Processing Record 30 of Set 9 | mackenzie
# Processing Record 31 of Set 9 | sisimiut
# Processing Record 32 of Set 9 | leningradskiy
# Processing Record 33 of Set 9 | qurunbaliyah
# City not found. Skipping...
# Processing Record 34 of Set 9 | miraflores
# Processing Record 35 of Set 9 | katha
# City not found. Skipping...
# Processing Record 36 of Set 9 | mackay
# Processing Record 37 of Set 9 | lagoa
# Processing Record 38 of Set 9 | fare
# Processing Record 39 of Set 9 | san cristobal
# Processing Record 40 of Set 9 | benghazi
# Processing Record 41 of Set 9 | nyirmeggyes
# Processing Record 42 of Set 9 | viransehir
# Processing Record 43 of Set 9 | tyup
# Processing Record 44 of Set 9 | diego de almagro
# Processing Record 45 of Set 9 | quatre cocos
# Processing Record 46 of Set 9 | pula
# Processing Record 47 of Set 9 | tanete
# Processing Record 48 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 49 of Set 9 | tawang
# Processing Record 50 of Set 9 | halden
# Processing Record 1 of Set 10 | pervomayskoye
# Processing Record 2 of Set 10 | haines junction
# Processing Record 3 of Set 10 | slave lake
# Processing Record 4 of Set 10 | livingstone
# Processing Record 5 of Set 10 | karratha
# Processing Record 6 of Set 10 | kinsale
# Processing Record 7 of Set 10 | maua
# Processing Record 8 of Set 10 | rumphi
# Processing Record 9 of Set 10 | zhigansk
# Processing Record 10 of Set 10 | ejura
# Processing Record 11 of Set 10 | toucheng
# Processing Record 12 of Set 10 | caravelas
# Processing Record 13 of Set 10 | vostok
# Processing Record 14 of Set 10 | thaton
# Processing Record 15 of Set 10 | rocha
# Processing Record 16 of Set 10 | campiglia marittima
# Processing Record 17 of Set 10 | tuy hoa
# Processing Record 18 of Set 10 | vestmannaeyjar
# Processing Record 19 of Set 10 | bandarbeyla
# Processing Record 20 of Set 10 | lima
# Processing Record 21 of Set 10 | guadalupe y calvo
# Processing Record 22 of Set 10 | la palma
# Processing Record 23 of Set 10 | aklavik
# Processing Record 24 of Set 10 | santa maria
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | ukrayinka
# Processing Record 27 of Set 10 | new milford
# Processing Record 28 of Set 10 | evensk
# Processing Record 29 of Set 10 | tarata
# Processing Record 30 of Set 10 | sistranda
# Processing Record 31 of Set 10 | sedan
# Processing Record 32 of Set 10 | tigil
# Processing Record 33 of Set 10 | basco
# Processing Record 34 of Set 10 | kano
# Processing Record 35 of Set 10 | cabedelo
# Processing Record 36 of Set 10 | guipavas
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | mbengwi
# Processing Record 39 of Set 10 | naryan-mar
# Processing Record 40 of Set 10 | evansville
# Processing Record 41 of Set 10 | phan thiet
# Processing Record 42 of Set 10 | sakakah
# Processing Record 43 of Set 10 | lavrentiya
# Processing Record 44 of Set 10 | am timan
# Processing Record 45 of Set 10 | nakur
# Processing Record 46 of Set 10 | buraydah
# Processing Record 47 of Set 10 | rawson
# Processing Record 48 of Set 10 | puerto escondido
# Processing Record 49 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 10 | langenburg
# Processing Record 1 of Set 11 | hendek
# Processing Record 2 of Set 11 | la ronge
# Processing Record 3 of Set 11 | nanakuli
# Processing Record 4 of Set 11 | melo
# Processing Record 5 of Set 11 | axim
# Processing Record 6 of Set 11 | varhaug
# Processing Record 7 of Set 11 | kununurra
# Processing Record 8 of Set 11 | kupang
# Processing Record 9 of Set 11 | huarmey
# Processing Record 10 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 11 of Set 11 | gimli
# Processing Record 12 of Set 11 | yangjiang
# Processing Record 13 of Set 11 | pemba
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | catio
# Processing Record 16 of Set 11 | abingdon
# Processing Record 17 of Set 11 | saldanha
# Processing Record 18 of Set 11 | port hedland
# Processing Record 19 of Set 11 | nola
# Processing Record 20 of Set 11 | bonnyville
# Processing Record 21 of Set 11 | touros
# Processing Record 22 of Set 11 | shaunavon
# Processing Record 23 of Set 11 | praxedis guerrero
# Processing Record 24 of Set 11 | picayune
# Processing Record 25 of Set 11 | bowen
# Processing Record 26 of Set 11 | chara
# Processing Record 27 of Set 11 | rincon
# Processing Record 28 of Set 11 | jega
# Processing Record 29 of Set 11 | balasheyka
# Processing Record 30 of Set 11 | maneadero
# Processing Record 31 of Set 11 | istok
# Processing Record 32 of Set 11 | port hawkesbury
# Processing Record 33 of Set 11 | aden
# Processing Record 34 of Set 11 | hoima
# Processing Record 35 of Set 11 | aykhal
# Processing Record 36 of Set 11 | doha
# Processing Record 37 of Set 11 | galveston
# Processing Record 38 of Set 11 | ampanihy
# Processing Record 39 of Set 11 | kashi
# Processing Record 40 of Set 11 | misratah
# Processing Record 41 of Set 11 | port hardy
# Processing Record 42 of Set 11 | makakilo city
# Processing Record 43 of Set 11 | general roca
# Processing Record 44 of Set 11 | vardo
# Processing Record 45 of Set 11 | novoagansk
# Processing Record 46 of Set 11 | chicama
# Processing Record 47 of Set 11 | nome
# Processing Record 48 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 49 of Set 11 | mattru
# Processing Record 50 of Set 11 | kailua
# Processing Record 1 of Set 12 | senanga
# Processing Record 2 of Set 12 | cangzhou
# Processing Record 3 of Set 12 | kerouane
# Processing Record 4 of Set 12 | coquimbo
# Processing Record 5 of Set 12 | karakol
# Processing Record 6 of Set 12 | codrington
# Processing Record 7 of Set 12 | aviles
# Processing Record 8 of Set 12 | dumas
# Processing Record 9 of Set 12 | tautira
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | tukrah
# Processing Record 12 of Set 12 | kalmunai
# Processing Record 13 of Set 12 | tabalosos
# Processing Record 14 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 12 | padang
# Processing Record 16 of Set 12 | alto araguaia
# Processing Record 17 of Set 12 | rimavska sobota
# Processing Record 18 of Set 12 | flin flon
# Processing Record 19 of Set 12 | batangafo
# Processing Record 20 of Set 12 | grottammare
# Processing Record 21 of Set 12 | pemangkat
# Processing Record 22 of Set 12 | koszalin
# Processing Record 23 of Set 12 | qaqortoq
# Processing Record 24 of Set 12 | bathsheba
# Processing Record 25 of Set 12 | erzin
# Processing Record 26 of Set 12 | bela
# Processing Record 27 of Set 12 | san quintin
# Processing Record 28 of Set 12 | boyolangu
# Processing Record 29 of Set 12 | khandyga
# Processing Record 30 of Set 12 | tabon
# Processing Record 31 of Set 12 | miranda
# Processing Record 32 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 12 | hvide sande
# Processing Record 34 of Set 12 | troitsko-pechorsk
# Processing Record 35 of Set 12 | ojinaga
# Processing Record 36 of Set 12 | severo-kurilsk
# Processing Record 37 of Set 12 | eydhafushi
# Processing Record 38 of Set 12 | necochea
# Processing Record 39 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 12 | sal rei
# Processing Record 41 of Set 12 | chincholi
# Processing Record 42 of Set 12 | arbroath
# Processing Record 43 of Set 12 | pandhana
# Processing Record 44 of Set 12 | da nang
# Processing Record 45 of Set 12 | yima
# Processing Record 46 of Set 12 | lac-megantic
# Processing Record 47 of Set 12 | mongar
# Processing Record 48 of Set 12 | bubaque
# Processing Record 49 of Set 12 | auki
# Processing Record 50 of Set 12 | bontang
# Processing Record 1 of Set 13 | bennington
# Processing Record 2 of Set 13 | sao joao da barra
# Processing Record 3 of Set 13 | sayat
# Processing Record 4 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 5 of Set 13 | maniitsoq
# Processing Record 6 of Set 13 | paso de los toros
# Processing Record 7 of Set 13 | rapid valley
# Processing Record 8 of Set 13 | acapulco
# Processing Record 9 of Set 13 | san miguel
# Processing Record 10 of Set 13 | saint-augustin
# Processing Record 11 of Set 13 | tanout
# Processing Record 12 of Set 13 | bairiki
# Processing Record 13 of Set 13 | torres
# Processing Record 14 of Set 13 | high rock
# Processing Record 15 of Set 13 | maceio
# Processing Record 16 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 13 | vadso
# Processing Record 18 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 13 | ipeti
# City not found. Skipping...
# Processing Record 20 of Set 13 | okha
# Processing Record 21 of Set 13 | bandar-e lengeh
# Processing Record 22 of Set 13 | sao felix do xingu
# Processing Record 23 of Set 13 | oussouye
# Processing Record 24 of Set 13 | cairo
# Processing Record 25 of Set 13 | lipin bor
# Processing Record 26 of Set 13 | sukheke
# City not found. Skipping...
# Processing Record 27 of Set 13 | tuatapere
# Processing Record 28 of Set 13 | lucapa
# Processing Record 29 of Set 13 | cap malheureux
# Processing Record 30 of Set 13 | bambanglipuro
# Processing Record 31 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 32 of Set 13 | ambon
# Processing Record 33 of Set 13 | beidao
# Processing Record 34 of Set 13 | luwuk
# Processing Record 35 of Set 13 | kango
# Processing Record 36 of Set 13 | riosucio
# Processing Record 37 of Set 13 | port blair
# Processing Record 38 of Set 13 | tomatlan
# Processing Record 39 of Set 13 | outjo
# Processing Record 40 of Set 13 | tortoli
# Processing Record 41 of Set 13 | honningsvag
# Processing Record 42 of Set 13 | two hills
# Processing Record 43 of Set 13 | zhangjiakou
# Processing Record 44 of Set 13 | bella union
# Processing Record 45 of Set 13 | nyurba
# Processing Record 46 of Set 13 | manicore
# Processing Record 47 of Set 13 | guiyang
# Processing Record 48 of Set 13 | hovd
# Processing Record 49 of Set 13 | golyshmanovo
# Processing Record 50 of Set 13 | margate
# Processing Record 1 of Set 14 | springdale
# Processing Record 2 of Set 14 | kidal
# Processing Record 3 of Set 14 | mallaig
# Processing Record 4 of Set 14 | bereda
# Processing Record 5 of Set 14 | castelo branco
# Processing Record 6 of Set 14 | manali
# Processing Record 7 of Set 14 | falmouth
# Processing Record 8 of Set 14 | santa rosa de osos
# Processing Record 9 of Set 14 | staryy nadym
# Processing Record 10 of Set 14 | san angelo
# Processing Record 11 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 14 | shihezi
# Processing Record 13 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 14 | matagami
# Processing Record 15 of Set 14 | paamiut
# Processing Record 16 of Set 14 | nizwa
# Processing Record 17 of Set 14 | yar-sale
# Processing Record 18 of Set 14 | kaura namoda
# Processing Record 19 of Set 14 | trybukhivtsi
# Processing Record 20 of Set 14 | anchorage
# Processing Record 21 of Set 14 | pangody
# Processing Record 22 of Set 14 | fortaleza
# Processing Record 23 of Set 14 | chengde
# Processing Record 24 of Set 14 | olinda
# Processing Record 25 of Set 14 | shieli
# Processing Record 26 of Set 14 | camacupa
# Processing Record 27 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 14 | san jose
# Processing Record 29 of Set 14 | sikeston
# Processing Record 30 of Set 14 | anadyr
# Processing Record 31 of Set 14 | priiskovyy
# Processing Record 32 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 33 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 35 of Set 14 | turiacu
# Processing Record 36 of Set 14 | isla mujeres
# Processing Record 37 of Set 14 | carauari
# Processing Record 38 of Set 14 | tamandare
# Processing Record 39 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 14 | puerto del rosario
# Processing Record 41 of Set 14 | porto novo
# Processing Record 42 of Set 14 | aksarka
# Processing Record 43 of Set 14 | khasan
# Processing Record 44 of Set 14 | laki
# Processing Record 45 of Set 14 | meulaboh
# Processing Record 46 of Set 14 | filingue
# Processing Record 47 of Set 14 | salekhard
# Processing Record 48 of Set 14 | keetmanshoop
# Processing Record 49 of Set 14 | mundo nuevo
# Processing Record 50 of Set 14 | kushima
# Processing Record 1 of Set 15 | jinchang
# Processing Record 2 of Set 15 | coruripe
# Processing Record 3 of Set 15 | leogane
# Processing Record 4 of Set 15 | sochi
# Processing Record 5 of Set 15 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | nishihara
# Processing Record 7 of Set 15 | muravlenko
# Processing Record 8 of Set 15 | uva
# Processing Record 9 of Set 15 | nouadhibou
# Processing Record 10 of Set 15 | atyrau
# Processing Record 11 of Set 15 | black river
# Processing Record 12 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 15 | bodden town
# Processing Record 14 of Set 15 | labuhan
# Processing Record 15 of Set 15 | weligama
# Processing Record 16 of Set 15 | itarema
# Processing Record 17 of Set 15 | iralaya
# Processing Record 18 of Set 15 | bend
# Processing Record 19 of Set 15 | niigata
# Processing Record 20 of Set 15 | goderich
# Processing Record 21 of Set 15 | tezu
# Processing Record 22 of Set 15 | urusha
# Processing Record 23 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 15 | jiayuguan
# Processing Record 25 of Set 15 | nilokheri
# Processing Record 26 of Set 15 | tulun
# Processing Record 27 of Set 15 | taldan
# Processing Record 28 of Set 15 | asau
# Processing Record 29 of Set 15 | tungkang
# City not found. Skipping...
# Processing Record 30 of Set 15 | totness
# Processing Record 31 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 32 of Set 15 | kieta
# Processing Record 33 of Set 15 | roncesvalles
# Processing Record 34 of Set 15 | lagarto
# Processing Record 35 of Set 15 | nhamunda
# Processing Record 36 of Set 15 | joacaba
# Processing Record 37 of Set 15 | yukamenskoye
# Processing Record 38 of Set 15 | olafsvik
# Processing Record 39 of Set 15 | stornoway
# Processing Record 40 of Set 15 | abha
# Processing Record 41 of Set 15 | waingapu
# Processing Record 42 of Set 15 | bilibino
# Processing Record 43 of Set 15 | guerrero negro
# Processing Record 44 of Set 15 | rochester
# Processing Record 45 of Set 15 | castelo do piaui
# Processing Record 46 of Set 15 | polohy
# Processing Record 47 of Set 15 | cervo
# Processing Record 48 of Set 15 | piedras negras
# Processing Record 49 of Set 15 | nagato
# Processing Record 50 of Set 15 | suntar
# Processing Record 1 of Set 16 | daru
# Processing Record 2 of Set 16 | kamakwie
# Processing Record 3 of Set 16 | port macquarie
# Processing Record 4 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 5 of Set 16 | merauke
# Processing Record 6 of Set 16 | darnah
# Processing Record 7 of Set 16 | bumba
# Processing Record 8 of Set 16 | worland
# Processing Record 9 of Set 16 | canutama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#reorder columns
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Thompson      CA  55.7435  -97.8558     14.16        73         100
# 1        Albany      US  42.6001  -73.9662     31.37        74          32
# 2       Ushuaia      AR -54.8000  -68.3000     49.66        57          20
# 3     Jamestown      US  42.0970  -79.2353     27.72        79         100
# 4     Busselton      AU -33.6500  115.3333     68.04        57           0
# 5    Nanortalik      GL  60.1432  -45.2371      9.59        63           9
# 6       Erenhot      CN  43.6475  111.9767      9.73        77          20
# 7  Punta Arenas      CL -53.1500  -70.9167     53.71        54          75
# 8       Rikitea      PF -23.1203 -134.9692     78.96        71          81
# 9     Sinnamary      GF   5.3833  -52.9500     76.80        85          29
#
#    Wind Speed Current Description
# 0       13.80     overcast clouds
# 1        1.99    scattered clouds
# 2       11.50          few clouds
# 3       10.36     overcast clouds
# 4        6.31           clear sky
# 5       17.31           clear sky
# 6       10.49          few clouds
# 7       10.36       broken clouds
# 8       13.94          light rain
# 9        5.99    scattered clouds

# %%
# Create the output file (CSV).
output_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(WeatherPy_Database, index_label="City_ID")
