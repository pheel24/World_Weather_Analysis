# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy as citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 711

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+"e744b0a3a2a596b21e2a3ecb9a31b02b"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | geraldton
# Processing Record 3 of Set 1 | maragogi
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | waw
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | las vegas
# Processing Record 16 of Set 1 | goure
# Processing Record 17 of Set 1 | yulara
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | moron
# Processing Record 20 of Set 1 | hami
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | kavaratti
# Processing Record 24 of Set 1 | tazovskiy
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | alofi
# Processing Record 27 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 1 | matay
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | enshi
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | vila do maio
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | vila velha
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | eenhana
# Processing Record 39 of Set 1 | mporokoso
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | gigmoto
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | la asuncion
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | borskoye
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | nokaneng
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | sapa
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | westport
# Processing Record 4 of Set 2 | salym
# Processing Record 5 of Set 2 | port-cartier
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | amberley
# Processing Record 10 of Set 2 | kyabe
# Processing Record 11 of Set 2 | eldorado
# Processing Record 12 of Set 2 | nanortalik
# Processing Record 13 of Set 2 | vardo
# Processing Record 14 of Set 2 | miraflores
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 2 | carutapera
# Processing Record 20 of Set 2 | saskylakh
# Processing Record 21 of Set 2 | moerai
# Processing Record 22 of Set 2 | shingu
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | nadym
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | santiago del estero
# Processing Record 28 of Set 2 | davila
# Processing Record 29 of Set 2 | portland
# Processing Record 30 of Set 2 | saint-joseph
# Processing Record 31 of Set 2 | sao geraldo do araguaia
# Processing Record 32 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 33 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 2 | sorland
# Processing Record 37 of Set 2 | coquimbo
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | brae
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | clyde river
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | lluta
# Processing Record 46 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | kununurra
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | katsuura
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | lata
# Processing Record 3 of Set 3 | vanavara
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | grand gaube
# Processing Record 6 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | bulawayo
# Processing Record 9 of Set 3 | tombouctou
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | oro valley
# Processing Record 13 of Set 3 | zambezi
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | los llanos de aridane
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | sur
# Processing Record 18 of Set 3 | upernavik
# Processing Record 19 of Set 3 | bowen
# Processing Record 20 of Set 3 | kourou
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 3 | belyy yar
# Processing Record 24 of Set 3 | kamaishi
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | severnoye
# Processing Record 28 of Set 3 | quetta
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | bonavista
# Processing Record 31 of Set 3 | dingle
# Processing Record 32 of Set 3 | saint-georges
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | kungurtug
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | sylling
# Processing Record 37 of Set 3 | biak
# Processing Record 38 of Set 3 | tasiilaq
# Processing Record 39 of Set 3 | chincholi
# Processing Record 40 of Set 3 | wajima
# Processing Record 41 of Set 3 | sao joao da barra
# Processing Record 42 of Set 3 | yaan
# Processing Record 43 of Set 3 | severodvinsk
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | umm lajj
# Processing Record 46 of Set 3 | sola
# Processing Record 47 of Set 3 | scarborough
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | racine
# Processing Record 1 of Set 4 | mansa
# Processing Record 2 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | muros
# Processing Record 5 of Set 4 | gisborne
# Processing Record 6 of Set 4 | kuznechnoye
# Processing Record 7 of Set 4 | sarai
# Processing Record 8 of Set 4 | mirnyy
# Processing Record 9 of Set 4 | poum
# Processing Record 10 of Set 4 | komsomolskiy
# Processing Record 11 of Set 4 | kasempa
# Processing Record 12 of Set 4 | zabreh
# Processing Record 13 of Set 4 | amapa
# Processing Record 14 of Set 4 | kango
# Processing Record 15 of Set 4 | tautira
# Processing Record 16 of Set 4 | bambanglipuro
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | san quintin
# Processing Record 19 of Set 4 | raudeberg
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | nouadhibou
# Processing Record 22 of Set 4 | abu kamal
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | rabo de peixe
# Processing Record 25 of Set 4 | iralaya
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | lushunkou
# City not found. Skipping...
# Processing Record 29 of Set 4 | ust-kuyga
# Processing Record 30 of Set 4 | longyearbyen
# Processing Record 31 of Set 4 | inuvik
# Processing Record 32 of Set 4 | harbour breton
# Processing Record 33 of Set 4 | vaini
# Processing Record 34 of Set 4 | uberaba
# Processing Record 35 of Set 4 | luanda
# Processing Record 36 of Set 4 | tukrah
# Processing Record 37 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 4 | caravelas
# Processing Record 39 of Set 4 | gold coast
# Processing Record 40 of Set 4 | arraial do cabo
# Processing Record 41 of Set 4 | new milford
# Processing Record 42 of Set 4 | gamba
# Processing Record 43 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 4 | ponta do sol
# Processing Record 45 of Set 4 | banepa
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | sao gabriel da cachoeira
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | yellowknife
# Processing Record 50 of Set 4 | lorengau
# Processing Record 1 of Set 5 | coahuayana
# Processing Record 2 of Set 5 | orangeburg
# Processing Record 3 of Set 5 | mangan
# Processing Record 4 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 5 | gotsu
# Processing Record 6 of Set 5 | nizhnevartovsk
# Processing Record 7 of Set 5 | pemba
# Processing Record 8 of Set 5 | vaasa
# Processing Record 9 of Set 5 | aykhal
# Processing Record 10 of Set 5 | ahuimanu
# Processing Record 11 of Set 5 | ballina
# Processing Record 12 of Set 5 | saquarema
# Processing Record 13 of Set 5 | saint-philippe
# Processing Record 14 of Set 5 | huntington
# Processing Record 15 of Set 5 | dovbysh
# Processing Record 16 of Set 5 | broken hill
# Processing Record 17 of Set 5 | aden
# Processing Record 18 of Set 5 | vigrestad
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 5 | verkhoyansk
# Processing Record 22 of Set 5 | kavieng
# Processing Record 23 of Set 5 | karasjok
# Processing Record 24 of Set 5 | yar-sale
# Processing Record 25 of Set 5 | aksu
# Processing Record 26 of Set 5 | nuuk
# Processing Record 27 of Set 5 | kousseri
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | zhanaozen
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | iwanai
# Processing Record 32 of Set 5 | okha
# Processing Record 33 of Set 5 | manama
# Processing Record 34 of Set 5 | naryan-mar
# Processing Record 35 of Set 5 | torbay
# Processing Record 36 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 5 | tuatapere
# Processing Record 38 of Set 5 | dakar
# Processing Record 39 of Set 5 | ostrovnoy
# Processing Record 40 of Set 5 | dunedin
# Processing Record 41 of Set 5 | axim
# Processing Record 42 of Set 5 | kingsport
# Processing Record 43 of Set 5 | beaufort
# Processing Record 44 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 5 | te anau
# Processing Record 46 of Set 5 | zhigansk
# Processing Record 47 of Set 5 | rosetta
# Processing Record 48 of Set 5 | manaure
# Processing Record 49 of Set 5 | mareeba
# Processing Record 50 of Set 5 | liverpool
# Processing Record 1 of Set 6 | kibaya
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | anadyr
# Processing Record 4 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 6 | abha
# Processing Record 6 of Set 6 | fernie
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 6 | tabou
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | wilmington
# Processing Record 12 of Set 6 | garibaldi
# Processing Record 13 of Set 6 | mahanje
# Processing Record 14 of Set 6 | mount isa
# Processing Record 15 of Set 6 | tiznit
# Processing Record 16 of Set 6 | jinchang
# Processing Record 17 of Set 6 | tingi
# Processing Record 18 of Set 6 | medvezhyegorsk
# Processing Record 19 of Set 6 | chicama
# Processing Record 20 of Set 6 | san luis
# Processing Record 21 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 6 | gurupi
# Processing Record 23 of Set 6 | rawson
# Processing Record 24 of Set 6 | inverell
# Processing Record 25 of Set 6 | raditsa-krylovka
# Processing Record 26 of Set 6 | puerto del rosario
# Processing Record 27 of Set 6 | wamba
# Processing Record 28 of Set 6 | charters towers
# Processing Record 29 of Set 6 | krasnoarmeysk
# Processing Record 30 of Set 6 | dukat
# Processing Record 31 of Set 6 | namie
# Processing Record 32 of Set 6 | guiratinga
# Processing Record 33 of Set 6 | portobelo
# Processing Record 34 of Set 6 | macenta
# Processing Record 35 of Set 6 | ankang
# Processing Record 36 of Set 6 | maltahohe
# Processing Record 37 of Set 6 | leningradskiy
# Processing Record 38 of Set 6 | margate
# Processing Record 39 of Set 6 | galveston
# Processing Record 40 of Set 6 | esil
# Processing Record 41 of Set 6 | baoqing
# Processing Record 42 of Set 6 | paamiut
# Processing Record 43 of Set 6 | namatanai
# Processing Record 44 of Set 6 | menongue
# Processing Record 45 of Set 6 | port macquarie
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | tambovka
# Processing Record 48 of Set 6 | ilulissat
# Processing Record 49 of Set 6 | hualmay
# Processing Record 50 of Set 6 | dingzhou
# Processing Record 1 of Set 7 | nabire
# Processing Record 2 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 3 of Set 7 | ranong
# Processing Record 4 of Set 7 | eureka
# Processing Record 5 of Set 7 | tommot
# Processing Record 6 of Set 7 | mogadishu
# Processing Record 7 of Set 7 | ribeira grande
# Processing Record 8 of Set 7 | penzance
# Processing Record 9 of Set 7 | nanakuli
# Processing Record 10 of Set 7 | rio gallegos
# Processing Record 11 of Set 7 | horodkivka
# Processing Record 12 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 7 | bredasdorp
# Processing Record 14 of Set 7 | matir
# City not found. Skipping...
# Processing Record 15 of Set 7 | thunder bay
# Processing Record 16 of Set 7 | beringovskiy
# Processing Record 17 of Set 7 | nalut
# Processing Record 18 of Set 7 | maceio
# Processing Record 19 of Set 7 | boende
# Processing Record 20 of Set 7 | haines junction
# Processing Record 21 of Set 7 | mantua
# Processing Record 22 of Set 7 | guerrero negro
# Processing Record 23 of Set 7 | yeniseysk
# Processing Record 24 of Set 7 | vila franca do campo
# Processing Record 25 of Set 7 | araouane
# Processing Record 26 of Set 7 | vestmannaeyjar
# Processing Record 27 of Set 7 | tamandare
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | bartica
# Processing Record 30 of Set 7 | cape canaveral
# Processing Record 31 of Set 7 | krasnoselkup
# Processing Record 32 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 7 | athens
# Processing Record 34 of Set 7 | marawi
# Processing Record 35 of Set 7 | honningsvag
# Processing Record 36 of Set 7 | carauari
# Processing Record 37 of Set 7 | nassau
# Processing Record 38 of Set 7 | freeport
# Processing Record 39 of Set 7 | beloha
# Processing Record 40 of Set 7 | khani
# Processing Record 41 of Set 7 | marsa matruh
# Processing Record 42 of Set 7 | valparaiso
# Processing Record 43 of Set 7 | mackenzie
# Processing Record 44 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | sehithwa
# Processing Record 47 of Set 7 | beyneu
# Processing Record 48 of Set 7 | juegang
# Processing Record 49 of Set 7 | folkestone
# Processing Record 50 of Set 7 | mackay
# Processing Record 1 of Set 8 | linqing
# Processing Record 2 of Set 8 | pascagoula
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | kjollefjord
# Processing Record 5 of Set 8 | la libertad
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | saint-pierre
# Processing Record 8 of Set 8 | zhuanghe
# Processing Record 9 of Set 8 | sisimiut
# Processing Record 10 of Set 8 | biltine
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | baghdad
# Processing Record 14 of Set 8 | sibolga
# Processing Record 15 of Set 8 | conde
# Processing Record 16 of Set 8 | port lincoln
# Processing Record 17 of Set 8 | fairbanks
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | pathein
# Processing Record 20 of Set 8 | lodingen
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | presidencia roque saenz pena
# Processing Record 23 of Set 8 | bow island
# Processing Record 24 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 8 | gao
# Processing Record 26 of Set 8 | shache
# Processing Record 27 of Set 8 | smyshlyayevka
# Processing Record 28 of Set 8 | granville
# Processing Record 29 of Set 8 | altay
# Processing Record 30 of Set 8 | petropavlovka
# Processing Record 31 of Set 8 | broome
# Processing Record 32 of Set 8 | meulaboh
# Processing Record 33 of Set 8 | niquero
# Processing Record 34 of Set 8 | isiro
# Processing Record 35 of Set 8 | salihorsk
# Processing Record 36 of Set 8 | sham churasi
# Processing Record 37 of Set 8 | padang
# Processing Record 38 of Set 8 | ambilobe
# Processing Record 39 of Set 8 | camacha
# Processing Record 40 of Set 8 | dhone
# Processing Record 41 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 8 | borogontsy
# Processing Record 43 of Set 8 | uglovskoye
# Processing Record 44 of Set 8 | sayabec
# City not found. Skipping...
# Processing Record 45 of Set 8 | mount gambier
# Processing Record 46 of Set 8 | nelson bay
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | south lake tahoe
# Processing Record 49 of Set 8 | davenport
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | marzuq
# Processing Record 3 of Set 9 | cherskiy
# Processing Record 4 of Set 9 | fort nelson
# Processing Record 5 of Set 9 | san lorenzo
# Processing Record 6 of Set 9 | clocolan
# Processing Record 7 of Set 9 | fez
# Processing Record 8 of Set 9 | solnechnyy
# Processing Record 9 of Set 9 | porto novo
# Processing Record 10 of Set 9 | muroto
# Processing Record 11 of Set 9 | hammerfest
# Processing Record 12 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | karratha
# Processing Record 15 of Set 9 | basco
# Processing Record 16 of Set 9 | albania
# Processing Record 17 of Set 9 | kisangani
# Processing Record 18 of Set 9 | shimoda
# Processing Record 19 of Set 9 | kitaibaraki
# Processing Record 20 of Set 9 | vaitape
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | kahului
# Processing Record 23 of Set 9 | sistranda
# Processing Record 24 of Set 9 | kambove
# Processing Record 25 of Set 9 | jagdispur
# Processing Record 26 of Set 9 | port moresby
# Processing Record 27 of Set 9 | sabancuy
# Processing Record 28 of Set 9 | sept-iles
# Processing Record 29 of Set 9 | gazanjyk
# Processing Record 30 of Set 9 | oktyabrskoye
# Processing Record 31 of Set 9 | were ilu
# Processing Record 32 of Set 9 | chufarovo
# Processing Record 33 of Set 9 | ayan
# Processing Record 34 of Set 9 | bismil
# Processing Record 35 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 36 of Set 9 | francistown
# Processing Record 37 of Set 9 | valenca
# Processing Record 38 of Set 9 | kloulklubed
# Processing Record 39 of Set 9 | kosikha
# Processing Record 40 of Set 9 | samarai
# Processing Record 41 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 9 | plettenberg bay
# Processing Record 43 of Set 9 | chumphon
# Processing Record 44 of Set 9 | oranjemund
# Processing Record 45 of Set 9 | kati
# Processing Record 46 of Set 9 | wewak
# Processing Record 47 of Set 9 | san andres
# Processing Record 48 of Set 9 | jinchengjiang
# City not found. Skipping...
# Processing Record 49 of Set 9 | flinders
# Processing Record 50 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 10 | richards bay
# Processing Record 2 of Set 10 | port hedland
# Processing Record 3 of Set 10 | saint-francois
# Processing Record 4 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 6 of Set 10 | saint george
# Processing Record 7 of Set 10 | umm kaddadah
# Processing Record 8 of Set 10 | udomlya
# Processing Record 9 of Set 10 | mitsamiouli
# Processing Record 10 of Set 10 | traverse city
# Processing Record 11 of Set 10 | ocampo
# Processing Record 12 of Set 10 | callaway
# Processing Record 13 of Set 10 | olafsvik
# Processing Record 14 of Set 10 | chipinge
# Processing Record 15 of Set 10 | tarko-sale
# Processing Record 16 of Set 10 | yetkul
# Processing Record 17 of Set 10 | marinette
# Processing Record 18 of Set 10 | korla
# Processing Record 19 of Set 10 | panzhihua
# Processing Record 20 of Set 10 | outram
# Processing Record 21 of Set 10 | pokrovskoye
# Processing Record 22 of Set 10 | xique-xique
# Processing Record 23 of Set 10 | hasaki
# Processing Record 24 of Set 10 | kushmurun
# Processing Record 25 of Set 10 | yandoon
# City not found. Skipping...
# Processing Record 26 of Set 10 | victoria point
# Processing Record 27 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 10 | bubaque
# Processing Record 29 of Set 10 | wellingborough
# Processing Record 30 of Set 10 | ponta delgada
# Processing Record 31 of Set 10 | baykit
# Processing Record 32 of Set 10 | kizukuri
# Processing Record 33 of Set 10 | terme
# Processing Record 34 of Set 10 | diban
# Processing Record 35 of Set 10 | santa rosa
# Processing Record 36 of Set 10 | kabanjahe
# Processing Record 37 of Set 10 | tiarei
# Processing Record 38 of Set 10 | sioux lookout
# Processing Record 39 of Set 10 | barcelos
# Processing Record 40 of Set 10 | general pico
# Processing Record 41 of Set 10 | saint-augustin
# Processing Record 42 of Set 10 | snasa
# Processing Record 43 of Set 10 | lahaina
# Processing Record 44 of Set 10 | muisne
# Processing Record 45 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 46 of Set 10 | shkotovo-26
# City not found. Skipping...
# Processing Record 47 of Set 10 | itaituba
# Processing Record 48 of Set 10 | srednekolymsk
# Processing Record 49 of Set 10 | neuquen
# Processing Record 50 of Set 10 | kadhan
# Processing Record 1 of Set 11 | bintulu
# Processing Record 2 of Set 11 | college
# Processing Record 3 of Set 11 | vao
# Processing Record 4 of Set 11 | tuskegee
# Processing Record 5 of Set 11 | turukhansk
# Processing Record 6 of Set 11 | daokou
# Processing Record 7 of Set 11 | male
# Processing Record 8 of Set 11 | camacupa
# Processing Record 9 of Set 11 | takoradi
# Processing Record 10 of Set 11 | selty
# Processing Record 11 of Set 11 | sinegorye
# Processing Record 12 of Set 11 | maridi
# Processing Record 13 of Set 11 | mexico
# Processing Record 14 of Set 11 | arkhangelskoye
# Processing Record 15 of Set 11 | revelstoke
# Processing Record 16 of Set 11 | morant bay
# Processing Record 17 of Set 11 | tomatlan
# Processing Record 18 of Set 11 | kuusamo
# Processing Record 19 of Set 11 | hofn
# Processing Record 20 of Set 11 | maine-soroa
# Processing Record 21 of Set 11 | auki
# Processing Record 22 of Set 11 | faanui
# Processing Record 23 of Set 11 | olbia
# Processing Record 24 of Set 11 | tramore
# Processing Record 25 of Set 11 | narsaq
# Processing Record 26 of Set 11 | takaka
# Processing Record 27 of Set 11 | vizianagaram
# Processing Record 28 of Set 11 | pahrump
# Processing Record 29 of Set 11 | provideniya
# Processing Record 30 of Set 11 | kifri
# Processing Record 31 of Set 11 | san policarpo
# Processing Record 32 of Set 11 | gazli
# Processing Record 33 of Set 11 | olga
# Processing Record 34 of Set 11 | honiara
# Processing Record 35 of Set 11 | asau
# Processing Record 36 of Set 11 | bulgan
# Processing Record 37 of Set 11 | wadi maliz
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | la esperanza
# Processing Record 40 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 41 of Set 11 | key largo
# Processing Record 42 of Set 11 | jackson
# Processing Record 43 of Set 11 | khudumelapye
# Processing Record 44 of Set 11 | birao
# Processing Record 45 of Set 11 | antalaha
# Processing Record 46 of Set 11 | ukiah
# Processing Record 47 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 11 | ust-nera
# Processing Record 49 of Set 11 | shakhrinau
# City not found. Skipping...
# Processing Record 50 of Set 11 | maturin
# Processing Record 1 of Set 12 | darhan
# Processing Record 2 of Set 12 | san marcos
# Processing Record 3 of Set 12 | horta
# Processing Record 4 of Set 12 | pokosnoye
# Processing Record 5 of Set 12 | maner
# Processing Record 6 of Set 12 | mbala
# Processing Record 7 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 12 | nioro
# Processing Record 9 of Set 12 | wucheng
# Processing Record 10 of Set 12 | buena vista
# Processing Record 11 of Set 12 | kaseda
# Processing Record 12 of Set 12 | sabang
# Processing Record 13 of Set 12 | kalmunai
# Processing Record 14 of Set 12 | prince rupert
# Processing Record 15 of Set 12 | brigantine
# Processing Record 16 of Set 12 | shelburne
# Processing Record 17 of Set 12 | petrolina
# Processing Record 18 of Set 12 | cuiluan
# Processing Record 19 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 12 | banda aceh
# Processing Record 21 of Set 12 | lingao
# Processing Record 22 of Set 12 | acarau
# Processing Record 23 of Set 12 | novospasskoye
# Processing Record 24 of Set 12 | fortuna
# Processing Record 25 of Set 12 | chore
# City not found. Skipping...
# Processing Record 26 of Set 12 | lanigan
# Processing Record 27 of Set 12 | xuddur
# Processing Record 28 of Set 12 | labuan
# Processing Record 29 of Set 12 | lovozero
# Processing Record 30 of Set 12 | burica
# City not found. Skipping...
# Processing Record 31 of Set 12 | williston
# Processing Record 32 of Set 12 | artigas
# Processing Record 33 of Set 12 | sandur
# Processing Record 34 of Set 12 | poshekhonye
# Processing Record 35 of Set 12 | ust-maya
# Processing Record 36 of Set 12 | zeya
# Processing Record 37 of Set 12 | trinidad
# Processing Record 38 of Set 12 | salalah
# Processing Record 39 of Set 12 | othaya
# Processing Record 40 of Set 12 | chifeng
# Processing Record 41 of Set 12 | buala
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | chapais
# Processing Record 44 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 12 | labuhan
# Processing Record 46 of Set 12 | praia
# Processing Record 47 of Set 12 | dori
# Processing Record 48 of Set 12 | karpogory
# Processing Record 49 of Set 12 | san antonio
# Processing Record 50 of Set 12 | betanzos
# Processing Record 1 of Set 13 | albacete
# Processing Record 2 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 13 | kysyl-syr
# Processing Record 4 of Set 13 | kanniyakumari
# Processing Record 5 of Set 13 | seydi
# Processing Record 6 of Set 13 | enkoping
# Processing Record 7 of Set 13 | alta floresta
# Processing Record 8 of Set 13 | antsohihy
# Processing Record 9 of Set 13 | evanton
# Processing Record 10 of Set 13 | ahvaz
# Processing Record 11 of Set 13 | berbera
# Processing Record 12 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 13 | thoen
# Processing Record 14 of Set 13 | port blair
# Processing Record 15 of Set 13 | dalbandin
# Processing Record 16 of Set 13 | emet
# Processing Record 17 of Set 13 | dor marunt
# Processing Record 18 of Set 13 | marsh harbour
# Processing Record 19 of Set 13 | goya
# Processing Record 20 of Set 13 | hazorasp
# Processing Record 21 of Set 13 | muyezerskiy
# Processing Record 22 of Set 13 | mweka
# Processing Record 23 of Set 13 | kargasok
# Processing Record 24 of Set 13 | zapolyarnyy
# Processing Record 25 of Set 13 | acapulco
# Processing Record 26 of Set 13 | hervey bay
# Processing Record 27 of Set 13 | nevsehir
# Processing Record 28 of Set 13 | ottumwa
# Processing Record 29 of Set 13 | jaru
# Processing Record 30 of Set 13 | pacific grove
# Processing Record 31 of Set 13 | baracoa
# Processing Record 32 of Set 13 | wolmaranstad
# City not found. Skipping...
# Processing Record 33 of Set 13 | lagoa
# Processing Record 34 of Set 13 | metro
# Processing Record 35 of Set 13 | toribio
# Processing Record 36 of Set 13 | seoul
# Processing Record 37 of Set 13 | amarwara
# Processing Record 38 of Set 13 | marathon
# Processing Record 39 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 13 | havoysund
# Processing Record 41 of Set 13 | dekar
# Processing Record 42 of Set 13 | alpena
# Processing Record 43 of Set 13 | grindavik
# Processing Record 44 of Set 13 | klyuchi
# Processing Record 45 of Set 13 | pailon
# Processing Record 46 of Set 13 | vestmanna
# Processing Record 47 of Set 13 | joshimath
# Processing Record 48 of Set 13 | numazu
# Processing Record 49 of Set 13 | ambunti
# Processing Record 50 of Set 13 | mercedes
# Processing Record 1 of Set 14 | kaeo
# Processing Record 2 of Set 14 | mpongwe
# Processing Record 3 of Set 14 | putina
# Processing Record 4 of Set 14 | saint anthony
# Processing Record 5 of Set 14 | lensk
# Processing Record 6 of Set 14 | kailua
# Processing Record 7 of Set 14 | aviles
# Processing Record 8 of Set 14 | goderich
# Processing Record 9 of Set 14 | yashan
# Processing Record 10 of Set 14 | caernarfon
# Processing Record 11 of Set 14 | gleisdorf
# Processing Record 12 of Set 14 | ergani
# Processing Record 13 of Set 14 | meadow lake
# Processing Record 14 of Set 14 | andenes
# Processing Record 15 of Set 14 | prieska
# Processing Record 16 of Set 14 | aranos
# Processing Record 17 of Set 14 | champdani
# City not found. Skipping...
# Processing Record 18 of Set 14 | yuzhno-kurilsk
# Processing Record 19 of Set 14 | marshfield
# Processing Record 20 of Set 14 | katiola
# Processing Record 21 of Set 14 | edd
# Processing Record 22 of Set 14 | santa lucia
# Processing Record 23 of Set 14 | vanimo
# Processing Record 24 of Set 14 | sabalgarh
# Processing Record 25 of Set 14 | iskateley
# Processing Record 26 of Set 14 | barentu
# Processing Record 27 of Set 14 | taitung
# Processing Record 28 of Set 14 | angoram
# Processing Record 29 of Set 14 | negotin
# Processing Record 30 of Set 14 | canto do buriti
# Processing Record 31 of Set 14 | ust-kut
# Processing Record 32 of Set 14 | havelock
# Processing Record 33 of Set 14 | bagacay
# Processing Record 34 of Set 14 | lakeland
# Processing Record 35 of Set 14 | mao
# Processing Record 36 of Set 14 | lao cai
# Processing Record 37 of Set 14 | pangai
# Processing Record 38 of Set 14 | marystown
# Processing Record 39 of Set 14 | port augusta
# Processing Record 40 of Set 14 | shubarkuduk
# Processing Record 41 of Set 14 | rettikhovka
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | san cristobal
# Processing Record 44 of Set 14 | kenai
# Processing Record 45 of Set 14 | ouadda
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | san juan
# Processing Record 48 of Set 14 | plymouth
# Processing Record 49 of Set 14 | agropoli
# Processing Record 50 of Set 14 | zhuhai
# Processing Record 1 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 2 of Set 15 | valentin gomez farias
# Processing Record 3 of Set 15 | shonguy
# Processing Record 4 of Set 15 | svetlyy
# Processing Record 5 of Set 15 | russkaya polyana
# Processing Record 6 of Set 15 | inhambane
# Processing Record 7 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 15 | dunmore east
# Processing Record 9 of Set 15 | hobe sound
# Processing Record 10 of Set 15 | grand island
# Processing Record 11 of Set 15 | harper
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#reorder columns
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     79.00        71          45
# 1     Geraldton      AU -28.7667  114.6000     72.01        49          75
# 2      Maragogi      BR  -9.0122  -35.2225     78.93        76          37
# 3     Cape Town      ZA -33.9258   18.4232     64.27        85          20
# 4    Butaritari      KI   3.0707  172.7902     82.58        74          51
# 5        Hobart      AU -42.8794  147.3294     75.02        52          20
# 6  Punta Arenas      CL -53.1500  -70.9167     53.71        82          75
# 7     Mahebourg      MU -20.4081   57.7000     79.09        83          40
# 8      Hermanus      ZA -34.4187   19.2345     63.90        93          91
# 9       Ushuaia      AR -54.8000  -68.3000     60.46        63          75
#
#    Wind Speed Current Description
# 0       19.26    scattered clouds
# 1       13.80       broken clouds
# 2        9.98    scattered clouds
# 3        3.44          few clouds
# 4       15.28       broken clouds
# 5        1.01          few clouds
# 6        9.22       broken clouds
# 7        8.05    scattered clouds
# 8        3.22     overcast clouds
# 9        6.91       broken clouds
