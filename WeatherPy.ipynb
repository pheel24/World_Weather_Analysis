# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy as citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+"e744b0a3a2a596b21e2a3ecb9a31b02b"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | myanaung
# Processing Record 2 of Set 1 | bathsheba
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | saint anthony
# Processing Record 6 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | ust-omchug
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | dingle
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | enid
# Processing Record 17 of Set 1 | trincomalee
# Processing Record 18 of Set 1 | kankan
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | kropotkin
# Processing Record 21 of Set 1 | flin flon
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | taoudenni
# Processing Record 24 of Set 1 | dharangaon
# Processing Record 25 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 1 | sao filipe
# Processing Record 27 of Set 1 | tiznit
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | bara
# Processing Record 30 of Set 1 | ous
# Processing Record 31 of Set 1 | presidente epitacio
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | haines junction
# Processing Record 36 of Set 1 | bud
# Processing Record 37 of Set 1 | aasiaat
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | guerrero negro
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | umm kaddadah
# Processing Record 44 of Set 1 | belaya gora
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | lavrentiya
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | mattoon
# Processing Record 50 of Set 1 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | birao
# Processing Record 3 of Set 2 | saucillo
# Processing Record 4 of Set 2 | canutama
# Processing Record 5 of Set 2 | parambu
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | dakar
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | gloversville
# Processing Record 10 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | kawalu
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | husavik
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | smithers
# Processing Record 20 of Set 2 | glushkovo
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | torbay
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | umm lajj
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | atar
# Processing Record 29 of Set 2 | hermanus
# Processing Record 30 of Set 2 | srivardhan
# Processing Record 31 of Set 2 | kutum
# Processing Record 32 of Set 2 | skovde
# City not found. Skipping...
# Processing Record 33 of Set 2 | banikoara
# Processing Record 34 of Set 2 | maniitsoq
# Processing Record 35 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 2 | datong
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | arlit
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | kenai
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | novyy urengoy
# Processing Record 46 of Set 2 | darhan
# Processing Record 47 of Set 2 | rikitea
# Processing Record 48 of Set 2 | meulaboh
# Processing Record 49 of Set 2 | mareeba
# Processing Record 50 of Set 2 | wana
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | coahuayana
# Processing Record 4 of Set 3 | salalah
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | nsanje
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | hornepayne
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | dabrowa tarnowska
# Processing Record 15 of Set 3 | yumen
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | henties bay
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | qaqortoq
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | aksarka
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | somotillo
# Processing Record 25 of Set 3 | naryan-mar
# Processing Record 26 of Set 3 | lai
# Processing Record 27 of Set 3 | balkhash
# Processing Record 28 of Set 3 | bagdarin
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | safaga
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | opportunity
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | damara
# Processing Record 35 of Set 3 | georgetown
# Processing Record 36 of Set 3 | pyinmana
# Processing Record 37 of Set 3 | praya
# Processing Record 38 of Set 3 | pinsk
# Processing Record 39 of Set 3 | kaeo
# Processing Record 40 of Set 3 | muros
# Processing Record 41 of Set 3 | tonj
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | sola
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | havoysund
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | jalu
# Processing Record 48 of Set 3 | sigulda
# Processing Record 49 of Set 3 | hvolsvollur
# Processing Record 50 of Set 3 | jamestown
# Processing Record 1 of Set 4 | alofi
# Processing Record 2 of Set 4 | bethel
# Processing Record 3 of Set 4 | fort nelson
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | brae
# Processing Record 6 of Set 4 | farah
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | george
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | mayumba
# Processing Record 11 of Set 4 | sept-iles
# Processing Record 12 of Set 4 | koson
# Processing Record 13 of Set 4 | moncagua
# Processing Record 14 of Set 4 | severo-kurilsk
# Processing Record 15 of Set 4 | sao sebastiao
# Processing Record 16 of Set 4 | lasa
# Processing Record 17 of Set 4 | junagarh
# Processing Record 18 of Set 4 | porbandar
# Processing Record 19 of Set 4 | talara
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | bagn
# Processing Record 23 of Set 4 | fairbanks
# Processing Record 24 of Set 4 | lumeje
# Processing Record 25 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 26 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 4 | nampula
# Processing Record 28 of Set 4 | rio gallegos
# Processing Record 29 of Set 4 | ikom
# Processing Record 30 of Set 4 | sangin
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | kodiak
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | dong xoai
# Processing Record 36 of Set 4 | sao joao da barra
# Processing Record 37 of Set 4 | milkovo
# Processing Record 38 of Set 4 | mar del plata
# Processing Record 39 of Set 4 | vanavara
# Processing Record 40 of Set 4 | ugoofaaru
# Processing Record 41 of Set 4 | komsomolskiy
# Processing Record 42 of Set 4 | tabas
# Processing Record 43 of Set 4 | esperance
# Processing Record 44 of Set 4 | linjiang
# Processing Record 45 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 4 | almendralejo
# Processing Record 47 of Set 4 | duzce
# Processing Record 48 of Set 4 | semnan
# Processing Record 49 of Set 4 | ouadda
# Processing Record 50 of Set 4 | raga
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | dubrovka
# Processing Record 3 of Set 5 | puerto carreno
# Processing Record 4 of Set 5 | taboshar
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | tura
# Processing Record 7 of Set 5 | walvis bay
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | dharchula
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | vikulovo
# Processing Record 12 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 13 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 5 | hilo
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | nieuw amsterdam
# Processing Record 17 of Set 5 | blythe
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | medicine hat
# Processing Record 20 of Set 5 | moorhead
# Processing Record 21 of Set 5 | marzuq
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | awjilah
# Processing Record 24 of Set 5 | shingu
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | hun
# Processing Record 29 of Set 5 | villa rica
# Processing Record 30 of Set 5 | barrow
# Processing Record 31 of Set 5 | paragominas
# Processing Record 32 of Set 5 | poli
# Processing Record 33 of Set 5 | matay
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | vestmannaeyjar
# Processing Record 37 of Set 5 | talcahuano
# Processing Record 38 of Set 5 | alekseyevsk
# Processing Record 39 of Set 5 | abdanan
# Processing Record 40 of Set 5 | cuiluan
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | sarakhs
# Processing Record 44 of Set 5 | san luis
# Processing Record 45 of Set 5 | calvinia
# Processing Record 46 of Set 5 | kismayo
# Processing Record 47 of Set 5 | springbok
# Processing Record 48 of Set 5 | matsanga
# City not found. Skipping...
# Processing Record 49 of Set 5 | samarai
# Processing Record 50 of Set 5 | dekernes
# Processing Record 1 of Set 6 | vaitape
# Processing Record 2 of Set 6 | ereymentau
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | frutal
# Processing Record 5 of Set 6 | tilichiki
# Processing Record 6 of Set 6 | mezen
# Processing Record 7 of Set 6 | port-cartier
# Processing Record 8 of Set 6 | bousso
# Processing Record 9 of Set 6 | egvekinot
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | hinton
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 6 | lukovetskiy
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | bahraich
# Processing Record 17 of Set 6 | pangai
# Processing Record 18 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 6 | banon
# Processing Record 20 of Set 6 | kerrville
# Processing Record 21 of Set 6 | ucluelet
# Processing Record 22 of Set 6 | kapaa
# Processing Record 23 of Set 6 | eydhafushi
# Processing Record 24 of Set 6 | gualeguay
# Processing Record 25 of Set 6 | luanda
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | cockburn town
# Processing Record 28 of Set 6 | ilulissat
# Processing Record 29 of Set 6 | havre-saint-pierre
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | baculin
# Processing Record 32 of Set 6 | harnoli
# Processing Record 33 of Set 6 | cholan
# City not found. Skipping...
# Processing Record 34 of Set 6 | trinidad
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | baruun-urt
# Processing Record 37 of Set 6 | dukat
# Processing Record 38 of Set 6 | smirnykh
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | hualmay
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | upernavik
# Processing Record 43 of Set 6 | wanderlandia
# City not found. Skipping...
# Processing Record 44 of Set 6 | montlucon
# Processing Record 45 of Set 6 | asau
# Processing Record 46 of Set 6 | dolores
# Processing Record 47 of Set 6 | saint-pierre
# Processing Record 48 of Set 6 | nyrob
# Processing Record 49 of Set 6 | yandyki
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 7 | giubiasco
# Processing Record 3 of Set 7 | nikolayevsk-na-amure
# Processing Record 4 of Set 7 | panjab
# Processing Record 5 of Set 7 | yekaterinoslavka
# Processing Record 6 of Set 7 | hadgaon
# Processing Record 7 of Set 7 | kovernino
# Processing Record 8 of Set 7 | nefteabad
# City not found. Skipping...
# Processing Record 9 of Set 7 | longyearbyen
# Processing Record 10 of Set 7 | kota kinabalu
# Processing Record 11 of Set 7 | mayna
# Processing Record 12 of Set 7 | hay river
# Processing Record 13 of Set 7 | partizanskoye
# Processing Record 14 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 7 | vardo
# Processing Record 16 of Set 7 | labuhan
# Processing Record 17 of Set 7 | nipawin
# Processing Record 18 of Set 7 | kedrovoye
# Processing Record 19 of Set 7 | yar-sale
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | shakawe
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | abu zabad
# Processing Record 24 of Set 7 | grants pass
# Processing Record 25 of Set 7 | hangu
# Processing Record 26 of Set 7 | jiaozuo
# Processing Record 27 of Set 7 | kapuskasing
# Processing Record 28 of Set 7 | margate
# Processing Record 29 of Set 7 | abu dhabi
# Processing Record 30 of Set 7 | iralaya
# Processing Record 31 of Set 7 | kishtwar
# Processing Record 32 of Set 7 | at-bashi
# Processing Record 33 of Set 7 | port macquarie
# Processing Record 34 of Set 7 | okandja
# City not found. Skipping...
# Processing Record 35 of Set 7 | mabaruma
# Processing Record 36 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 37 of Set 7 | quatre cocos
# Processing Record 38 of Set 7 | saldanha
# Processing Record 39 of Set 7 | biak
# Processing Record 40 of Set 7 | caravelas
# Processing Record 41 of Set 7 | evensk
# Processing Record 42 of Set 7 | sydney
# Processing Record 43 of Set 7 | shimoda
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | sarkand
# Processing Record 46 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 7 | aklavik
# Processing Record 48 of Set 7 | englehart
# Processing Record 49 of Set 7 | riaba
# City not found. Skipping...
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | nome
# Processing Record 2 of Set 8 | ilebo
# Processing Record 3 of Set 8 | swan river
# Processing Record 4 of Set 8 | denpasar
# Processing Record 5 of Set 8 | tateyama
# Processing Record 6 of Set 8 | nemuro
# Processing Record 7 of Set 8 | marawi
# Processing Record 8 of Set 8 | molokovo
# Processing Record 9 of Set 8 | warrnambool
# Processing Record 10 of Set 8 | namibe
# Processing Record 11 of Set 8 | havelock
# Processing Record 12 of Set 8 | lubao
# Processing Record 13 of Set 8 | ayagoz
# Processing Record 14 of Set 8 | vestmanna
# Processing Record 15 of Set 8 | hede
# Processing Record 16 of Set 8 | taseyevo
# Processing Record 17 of Set 8 | berlevag
# Processing Record 18 of Set 8 | suratgarh
# Processing Record 19 of Set 8 | solwezi
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | general roca
# Processing Record 22 of Set 8 | palana
# Processing Record 23 of Set 8 | sinnamary
# Processing Record 24 of Set 8 | khunti
# Processing Record 25 of Set 8 | gat
# Processing Record 26 of Set 8 | presidencia roque saenz pena
# Processing Record 27 of Set 8 | penukonda
# Processing Record 28 of Set 8 | varkkallai
# Processing Record 29 of Set 8 | aguimes
# Processing Record 30 of Set 8 | salinopolis
# Processing Record 31 of Set 8 | porto novo
# Processing Record 32 of Set 8 | venkatagiri
# Processing Record 33 of Set 8 | fort dodge
# Processing Record 34 of Set 8 | catamarca
# Processing Record 35 of Set 8 | yerofey pavlovich
# Processing Record 36 of Set 8 | pisco
# Processing Record 37 of Set 8 | iqaluit
# Processing Record 38 of Set 8 | kalabo
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | saint-augustin
# Processing Record 41 of Set 8 | taungdwingyi
# Processing Record 42 of Set 8 | muisne
# Processing Record 43 of Set 8 | rostovka
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | aykhal
# Processing Record 46 of Set 8 | middelkerke
# Processing Record 47 of Set 8 | kaili
# Processing Record 48 of Set 8 | belmonte
# Processing Record 49 of Set 8 | indramayu
# Processing Record 50 of Set 8 | khandwa
# Processing Record 1 of Set 9 | dubbo
# Processing Record 2 of Set 9 | cururupu
# Processing Record 3 of Set 9 | saint-fabien
# City not found. Skipping...
# Processing Record 4 of Set 9 | clarence town
# Processing Record 5 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 6 of Set 9 | killybegs
# Processing Record 7 of Set 9 | bonthe
# Processing Record 8 of Set 9 | cantanhede
# Processing Record 9 of Set 9 | puerto del rosario
# Processing Record 10 of Set 9 | wageningen
# Processing Record 11 of Set 9 | saint paul
# Processing Record 12 of Set 9 | kununurra
# Processing Record 13 of Set 9 | mocuba
# Processing Record 14 of Set 9 | nhulunbuy
# Processing Record 15 of Set 9 | aripuana
# Processing Record 16 of Set 9 | sidrolandia
# Processing Record 17 of Set 9 | la ciotat
# Processing Record 18 of Set 9 | lisakovsk
# Processing Record 19 of Set 9 | manzil tamim
# City not found. Skipping...
# Processing Record 20 of Set 9 | omsukchan
# Processing Record 21 of Set 9 | south lake tahoe
# Processing Record 22 of Set 9 | bunia
# Processing Record 23 of Set 9 | the pas
# Processing Record 24 of Set 9 | poum
# Processing Record 25 of Set 9 | riyadh
# Processing Record 26 of Set 9 | nagua
# Processing Record 27 of Set 9 | birin
# Processing Record 28 of Set 9 | roald
# Processing Record 29 of Set 9 | tigil
# Processing Record 30 of Set 9 | strelka
# Processing Record 31 of Set 9 | berdigestyakh
# Processing Record 32 of Set 9 | san jose
# Processing Record 33 of Set 9 | alta floresta
# Processing Record 34 of Set 9 | ust-kuyga
# Processing Record 35 of Set 9 | kangaatsiaq
# Processing Record 36 of Set 9 | ust-tsilma
# Processing Record 37 of Set 9 | dhidhdhoo
# Processing Record 38 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 9 | the valley
# Processing Record 40 of Set 9 | bubaque
# Processing Record 41 of Set 9 | homer
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | esna
# Processing Record 44 of Set 9 | la ronge
# Processing Record 45 of Set 9 | laguna
# Processing Record 46 of Set 9 | yuanping
# Processing Record 47 of Set 9 | hamilton
# Processing Record 48 of Set 9 | bardiyah
# Processing Record 49 of Set 9 | whitehorse
# Processing Record 50 of Set 9 | daboh
# Processing Record 1 of Set 10 | sal rei
# Processing Record 2 of Set 10 | portland
# Processing Record 3 of Set 10 | kasongo-lunda
# Processing Record 4 of Set 10 | huarmey
# Processing Record 5 of Set 10 | bosaso
# Processing Record 6 of Set 10 | norsup
# Processing Record 7 of Set 10 | bundaberg
# Processing Record 8 of Set 10 | nurota
# Processing Record 9 of Set 10 | honningsvag
# Processing Record 10 of Set 10 | santa maria
# Processing Record 11 of Set 10 | avera
# Processing Record 12 of Set 10 | alice
# Processing Record 13 of Set 10 | karatuzskoye
# Processing Record 14 of Set 10 | atambua
# Processing Record 15 of Set 10 | kartuzy
# Processing Record 16 of Set 10 | itarema
# Processing Record 17 of Set 10 | caruray
# Processing Record 18 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 10 | chiungutwa
# Processing Record 20 of Set 10 | matagami
# Processing Record 21 of Set 10 | manado
# Processing Record 22 of Set 10 | paamiut
# Processing Record 23 of Set 10 | mayor pablo lagerenza
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | merauke
# Processing Record 26 of Set 10 | tessalit
# Processing Record 27 of Set 10 | port blair
# Processing Record 28 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 10 | molina
# Processing Record 30 of Set 10 | ostrovnoy
# Processing Record 31 of Set 10 | am timan
# Processing Record 32 of Set 10 | nikki
# Processing Record 33 of Set 10 | sale
# Processing Record 34 of Set 10 | north bend
# Processing Record 35 of Set 10 | doha
# Processing Record 36 of Set 10 | batagay-alyta
# Processing Record 37 of Set 10 | crown point
# Processing Record 38 of Set 10 | teknaf
# Processing Record 39 of Set 10 | hambantota
# Processing Record 40 of Set 10 | pemangkat
# Processing Record 41 of Set 10 | intipuca
# Processing Record 42 of Set 10 | acara
# Processing Record 43 of Set 10 | novoagansk
# Processing Record 44 of Set 10 | antofagasta
# Processing Record 45 of Set 10 | ivanava
# Processing Record 46 of Set 10 | rapid city
# Processing Record 47 of Set 10 | naze
# Processing Record 48 of Set 10 | hofn
# Processing Record 49 of Set 10 | ustrzyki dolne
# Processing Record 50 of Set 10 | general pico
# Processing Record 1 of Set 11 | maceio
# Processing Record 2 of Set 11 | ginda
# Processing Record 3 of Set 11 | turukhansk
# Processing Record 4 of Set 11 | porto velho
# Processing Record 5 of Set 11 | westport
# Processing Record 6 of Set 11 | teguldet
# Processing Record 7 of Set 11 | college
# Processing Record 8 of Set 11 | san juan
# Processing Record 9 of Set 11 | akureyri
# Processing Record 10 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 11 | kamskiye polyany
# Processing Record 12 of Set 11 | okha
# Processing Record 13 of Set 11 | filingue
# Processing Record 14 of Set 11 | puerto montt
# Processing Record 15 of Set 11 | kharan
# Processing Record 16 of Set 11 | gobabis
# Processing Record 17 of Set 11 | peniche
# Processing Record 18 of Set 11 | alice springs
# Processing Record 19 of Set 11 | chapayevka
# Processing Record 20 of Set 11 | vao
# Processing Record 21 of Set 11 | santa fe
# Processing Record 22 of Set 11 | micheweni
# Processing Record 23 of Set 11 | reconquista
# Processing Record 24 of Set 11 | alyangula
# Processing Record 25 of Set 11 | rincon
# Processing Record 26 of Set 11 | teya
# Processing Record 27 of Set 11 | mujiayingzi
# Processing Record 28 of Set 11 | dongsheng
# Processing Record 29 of Set 11 | grindavik
# Processing Record 30 of Set 11 | santa rosa
# Processing Record 31 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 11 | oranjemund
# Processing Record 33 of Set 11 | paita
# Processing Record 34 of Set 11 | ulladulla
# Processing Record 35 of Set 11 | laguna de perlas
# Processing Record 36 of Set 11 | valentin gomez farias
# Processing Record 37 of Set 11 | parauna
# Processing Record 38 of Set 11 | codrington
# Processing Record 39 of Set 11 | bergerac
# Processing Record 40 of Set 11 | ahipara
# Processing Record 41 of Set 11 | hasaki
# Processing Record 42 of Set 11 | mexicali
# Processing Record 43 of Set 11 | sioux lookout
# Processing Record 44 of Set 11 | shimanovsk
# Processing Record 45 of Set 11 | kurumkan
# Processing Record 46 of Set 11 | oranjestad
# Processing Record 47 of Set 11 | victoria
# Processing Record 48 of Set 11 | nuuk
# Processing Record 49 of Set 11 | bitburg
# Processing Record 50 of Set 11 | mehran
# Processing Record 1 of Set 12 | ixtapa
# Processing Record 2 of Set 12 | banda aceh
# Processing Record 3 of Set 12 | kungurtug
# Processing Record 4 of Set 12 | russell
# Processing Record 5 of Set 12 | manakara
# Processing Record 6 of Set 12 | tazovskiy
# Processing Record 7 of Set 12 | kieta
# Processing Record 8 of Set 12 | high level
# Processing Record 9 of Set 12 | barao de melgaco
# Processing Record 10 of Set 12 | huancabamba
# Processing Record 11 of Set 12 | sandominic
# Processing Record 12 of Set 12 | soyo
# Processing Record 13 of Set 12 | athabasca
# Processing Record 14 of Set 12 | lata
# Processing Record 15 of Set 12 | corn island
# Processing Record 16 of Set 12 | farafangana
# Processing Record 17 of Set 12 | wajid
# Processing Record 18 of Set 12 | nebolchi
# Processing Record 19 of Set 12 | bull savanna
# Processing Record 20 of Set 12 | astipalaia
# City not found. Skipping...
# Processing Record 21 of Set 12 | namatanai
# Processing Record 22 of Set 12 | sechura
# Processing Record 23 of Set 12 | bati
# Processing Record 24 of Set 12 | luneville
# Processing Record 25 of Set 12 | ganzhou
# Processing Record 26 of Set 12 | taranto
# Processing Record 27 of Set 12 | joniskelis
# Processing Record 28 of Set 12 | tadine
# Processing Record 29 of Set 12 | padang
# Processing Record 30 of Set 12 | taltal
# Processing Record 31 of Set 12 | araouane
# Processing Record 32 of Set 12 | richards bay
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | isilkul
# Processing Record 35 of Set 12 | navapur
# City not found. Skipping...
# Processing Record 36 of Set 12 | nanortalik
# Processing Record 37 of Set 12 | lodja
# Processing Record 38 of Set 12 | gizo
# Processing Record 39 of Set 12 | krasnoselkup
# Processing Record 40 of Set 12 | dromolaxia
# Processing Record 41 of Set 12 | balakirevo
# Processing Record 42 of Set 12 | dudinka
# Processing Record 43 of Set 12 | kristianstad
# Processing Record 44 of Set 12 | itoman
# Processing Record 45 of Set 12 | victor harbor
# Processing Record 46 of Set 12 | mangan
# Processing Record 47 of Set 12 | consuegra
# Processing Record 48 of Set 12 | chardara
# Processing Record 49 of Set 12 | kysyl-syr
# Processing Record 50 of Set 12 | boshnyakovo
# Processing Record 1 of Set 13 | praia
# Processing Record 2 of Set 13 | laibin
# Processing Record 3 of Set 13 | buta
# Processing Record 4 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 13 | valdivia
# Processing Record 6 of Set 13 | eenhana
# Processing Record 7 of Set 13 | sterling
# Processing Record 8 of Set 13 | sao felix do xingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Myanaung  18.2833   95.3167     64.17        68          22
# 1        Bathsheba  13.2167  -59.5167     77.61        69          20
# 2        Hithadhoo  -0.6000   73.0833     81.10        69          79
# 3    Saint Anthony  45.0205  -93.2180     22.93        49           0
# 4          Ushuaia -54.8000  -68.3000     51.46        71          75
# 5       Ust-Omchug  61.1500  149.6333     -9.76        99         100
# 6  Bambous Virieux -20.3428   57.7575     75.45        78          20
# 7          Kavieng  -2.5744  150.7967     84.83        67          69
# 8           Atuona  -9.8000 -139.0333     78.33        78           2
# 9            Bluff -46.6000  168.3333     62.80        57          70
#
#    Wind Speed Country                 Date
# 0        3.69      MM  2022-01-27 22:38:12
# 1       10.36      BB  2022-01-27 22:38:12
# 2       15.01      MV  2022-01-27 22:38:13
# 3       11.50      US  2022-01-27 22:38:13
# 4       14.97      AR  2022-01-27 22:33:50
# 5        9.71      RU  2022-01-27 22:38:14
# 6        3.44      MU  2022-01-27 22:38:14
# 7        7.14      PG  2022-01-27 22:38:15
# 8       17.90      PF  2022-01-27 22:38:15
# 9        4.27      NZ  2022-01-27 22:38:15

# %%
#reorder columns
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df=city_data_df[new_column_order]
#city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))

# %%
#LinReg for S hemisphere
x_values_sh=southern_hemi_df["Lat"]
y_values_sh=southern_hemi_df["Max Temp"]
#call fn
plot_linear_regression(x_values_sh, y_values_sh,
                       'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp',(-50,85))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
#NH Lat vs Cloudiness plot
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Cloudiness"]
# call fn
plot_linear_regression(x_values,y_values,
                      'Linear Regression on the Northern Hemisphere for % Cloudiness','Cloudiness',(10,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Wind Speed', 'Wind Speed',(40,35))
